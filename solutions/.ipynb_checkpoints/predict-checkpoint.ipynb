# %%
import os

from IDRnD.utils import Train, seed_everything
from IDRnD.augmentations import ToMellSpec, PadOrClip, ToTensor, Normalize_predef
from IDRnD.dataset import Test_Dataset, get_train_data
from IDRnD.resnet import resnet18

import numpy as np
import pandas as pd
import librosa
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import transforms

seed_everything(0)

# %%
dataset_dir = "."

eval_protocol_path = "protocol_test.txt"
eval_protocol = pd.read_csv(eval_protocol_path, sep=" ", header=None)
eval_protocol.columns = ['path', 'key']
eval_protocol['score'] = 0.0
eval_protocol['path'] = eval_protocol['path'].apply(lambda x: os.path.join(dataset_dir, x))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5525a32554ce> in <module>
#       2
#       3 eval_protocol_path = "protocol_test.txt"
# ----> 4 eval_protocol = pd.read_csv(eval_protocol_path, sep=" ", header=None)
#       5 eval_protocol.columns = ['path', 'key']
#       6 eval_protocol['score'] = 0.0
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'protocol_test.txt' does not exist: b'protocol_test.txt'

# %%
post_transform = transforms.Compose([
    ToMellSpec(n_mels=128),
    Normalize_predef(-29.6179, 16.6342),
    librosa.power_to_db,
    PadOrClip(150),
    ToTensor(),
])

# %% [markdown]
# ### predict

# %%
X, y = get_train_data()

# %%
test_dataset = Test_Dataset(X)

# %%
lens = [len(test_dataset[i][0]) for i in range(len(test_dataset))]

# %%
mda = pd.DataFrame()
mda["path"] = X
mda["lens"] = lens

# %%
pd.set_option('max_colwidth', 80)

# %%
# %matplotlib inline
mda["lens"].hist(bins = 500)

# %%
wavs = [test_dataset[i][0] for i in range(len(test_dataset))]

# %%
from hashlib import sha1

hashes = []
for wav in wavs:
    hashes.append(sha1(wav).hexdigest())

# %%
mda["hashes"]=hashes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1618aea03175> in <module>
# ----> 1 mda["hashes"]=hashes
#
# NameError: name 'hashes' is not defined

# %%
mda.groupby("hashes")

# %%
len(set(hashes))

# %%
from collections import Counter
common_hashes = [i[0] for i in Counter(hashes).most_common(592)]

# %%
common_hashes

# %%
set(mda["lens"])

# %%
mda.sort_values("lens")[30000:]
# Out:
#                                                                 path    lens
# 18262  /src/workspace/data/files/Training_Data/spoof/spoof_07940.wav   67200
# 24605  /src/workspace/data/files/Training_Data/spoof/spoof_14283.wav   67200
# 49656  /src/workspace/data/files/Training_Data/spoof/spoof_39334.wav   67200
# 6390   /src/workspace/data/files/Training_Data/human/human_06390.wav   67200
# 46616  /src/workspace/data/files/Training_Data/spoof/spoof_36294.wav   67200
# 34585  /src/workspace/data/files/Training_Data/spoof/spoof_24263.wav   67200
# 20053  /src/workspace/data/files/Training_Data/spoof/spoof_09731.wav   67200
# 11676  /src/workspace/data/files/Training_Data/spoof/spoof_01354.wav   67200
# 18994  /src/workspace/data/files/Training_Data/spoof/spoof_08672.wav   67200
# 10891  /src/workspace/data/files/Training_Data/spoof/spoof_00569.wav   67200
# 30855  /src/workspace/data/files/Training_Data/spoof/spoof_20533.wav   67200
# 3001   /src/workspace/data/files/Training_Data/human/human_03001.wav   67200
# 25452  /src/workspace/data/files/Training_Data/spoof/spoof_15130.wav   67200
# 39854  /src/workspace/data/files/Training_Data/spoof/spoof_29532.wav  162240
# 16714  /src/workspace/data/files/Training_Data/spoof/spoof_06392.wav  162240
# 19299  /src/workspace/data/files/Training_Data/spoof/spoof_08977.wav  162240
# 31747  /src/workspace/data/files/Training_Data/spoof/spoof_21425.wav  162240
# 14536  /src/workspace/data/files/Training_Data/spoof/spoof_04214.wav  162240
# 44939  /src/workspace/data/files/Training_Data/spoof/spoof_34617.wav  162240
# 3485   /src/workspace/data/files/Training_Data/human/human_03485.wav  162240
# 1632   /src/workspace/data/files/Training_Data/human/human_01632.wav  162240
#
# [20000 rows x 2 columns]

# %%
hm = Train()

#test_dataset = Test_Dataset(eval_protocol["path"], post_transform)
test_dataset = Test_Dataset(X[:520], post_transform)

test_loader = DataLoader(test_dataset, batch_size=250, shuffle=False)

model = resnet18(num_classes=1).cuda()

#model.load_state_dict(torch.load('models/simple_old_conv.pt'))
#model_dst = torch.nn.DataParallel(model, device_ids=[0, 1]).cuda()
#torch.save(model_dst.module.state_dict(),  'models/kaggle2_nonparallel.pt') 
model.eval()
model.load_state_dict(torch.load('models/resnet_18_last_epoch.pt'))
pred = hm.predict_on_test(test_loader, model)

# %%
model(test_dataset[0][0].reshape(1, 1, 128, 150).cuda())
# Out:
# tensor([[1.9516e-06]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
mda = pd.DataFrame()
mda["path"] = X[:520]

# %%
mda["score"] = pred.values

# %%
mda
# Out:
#                                                   path         score
# 0    /src/workspace/data/files/Training_Data/human/...  3.746134e-06
# 1    /src/workspace/data/files/Training_Data/human/...  2.745747e-01
# 2    /src/workspace/data/files/Training_Data/human/...  7.009626e-12
# 3    /src/workspace/data/files/Training_Data/human/...  4.157010e-01
# 4    /src/workspace/data/files/Training_Data/human/...  2.967725e-01
# 5    /src/workspace/data/files/Training_Data/human/...  1.897165e-01
# 6    /src/workspace/data/files/Training_Data/human/...  4.357744e-01
# 7    /src/workspace/data/files/Training_Data/human/...  1.937179e-01
# 8    /src/workspace/data/files/Training_Data/human/...  4.595556e-01
# 9    /src/workspace/data/files/Training_Data/human/...  1.770746e-01
# 10   /src/workspace/data/files/Training_Data/human/...  2.051082e-01
# 11   /src/workspace/data/files/Training_Data/human/...  0.000000e+00
# 12   /src/workspace/data/files/Training_Data/human/...  1.331573e-01
# 13   /src/workspace/data/files/Training_Data/human/...  8.544966e-02
# 14   /src/workspace/data/files/Training_Data/human/...  2.902036e-01
# 15   /src/workspace/data/files/Training_Data/human/...  9.660208e-01
# 16   /src/workspace/data/files/Training_Data/human/...  6.019267e-01
# 17   /src/workspace/data/files/Training_Data/human/...  8.280740e-04
# 18   /src/workspace/data/files/Training_Data/human/...  5.787390e-02
# 19   /src/workspace/data/files/Training_Data/human/...  1.949434e-01
# 20   /src/workspace/data/files/Training_Data/human/...  1.358923e-06
# 21   /src/workspace/data/files/Training_Data/human/...  4.879814e-01
# 22   /src/workspace/data/files/Training_Data/human/...  6.997722e-02
# 23   /src/workspace/data/files/Training_Data/human/...  1.420327e-15
# 24   /src/workspace/data/files/Training_Data/human/...  4.137844e-01
# 25   /src/workspace/data/files/Training_Data/human/...  2.061394e-01
# 26   /src/workspace/data/files/Training_Data/human/...  2.033121e-01
# 27   /src/workspace/data/files/Training_Data/human/...  2.355814e-01
# 28   /src/workspace/data/files/Training_Data/human/...  7.730093e-01
# 29   /src/workspace/data/files/Training_Data/human/...  8.328321e-01
# ..                                                 ...           ...
# 490  /src/workspace/data/files/Training_Data/human/...  3.363352e-01
# 491  /src/workspace/data/files/Training_Data/human/...  4.781409e-02
# 492  /src/workspace/data/files/Training_Data/human/...  1.184994e-01
# 493  /src/workspace/data/files/Training_Data/human/...  1.913583e-01
# 494  /src/workspace/data/files/Training_Data/human/...  2.184855e-01
# 495  /src/workspace/data/files/Training_Data/human/...  6.297808e-02
# 496  /src/workspace/data/files/Training_Data/human/...  2.704573e-01
# 497  /src/workspace/data/files/Training_Data/human/...  2.604332e-11
# 498  /src/workspace/data/files/Training_Data/human/...  3.424906e-01
# 499  /src/workspace/data/files/Training_Data/human/...  5.639012e-05
# 500  /src/workspace/data/files/Training_Data/human/...  1.433578e-05
# 501  /src/workspace/data/files/Training_Data/human/...  1.304189e-02
# 502  /src/workspace/data/files/Training_Data/human/...  3.153311e-01
# 503  /src/workspace/data/files/Training_Data/human/...  2.363345e-01
# 504  /src/workspace/data/files/Training_Data/human/...  8.527388e-01
# 505  /src/workspace/data/files/Training_Data/human/...  2.625704e-06
# 506  /src/workspace/data/files/Training_Data/human/...  2.859475e-08
# 507  /src/workspace/data/files/Training_Data/human/...  3.595820e-02
# 508  /src/workspace/data/files/Training_Data/human/...  6.591675e-01
# 509  /src/workspace/data/files/Training_Data/human/...  9.243860e-01
# 510  /src/workspace/data/files/Training_Data/human/...  3.284304e-01
# 511  /src/workspace/data/files/Training_Data/human/...  1.162506e-11
# 512  /src/workspace/data/files/Training_Data/human/...  4.817064e-01
# 513  /src/workspace/data/files/Training_Data/human/...  1.058188e-04
# 514  /src/workspace/data/files/Training_Data/human/...  0.000000e+00
# 515  /src/workspace/data/files/Training_Data/human/...  8.882918e-18
# 516  /src/workspace/data/files/Training_Data/human/...  5.653164e-01
# 517  /src/workspace/data/files/Training_Data/human/...  8.091680e-01
# 518  /src/workspace/data/files/Training_Data/human/...  8.753541e-01
# 519  /src/workspace/data/files/Training_Data/human/...  3.451590e-02
#
# [520 rows x 2 columns]

# %%
eval_protocol["score"] = pred.values
eval_protocol[['path', 'score']].to_csv('answers.csv', index=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b1b24944f158> in <module>
# ----> 1 eval_protocol["score"] = pred.values
#       2 eval_protocol[['path', 'score']].to_csv('answers.csv', index=None)
#
# NameError: name 'eval_protocol' is not defined

# %%
# !jupyter nbconvert --to script predict.ipynb
# Out:
# [NbConvertApp] Converting notebook predict.ipynb to script
# [NbConvertApp] Writing 1657 bytes to predict.py

# %%
mda
